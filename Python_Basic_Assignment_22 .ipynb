# %% [markdown]
# ## 1. What is the result of the code, and explain?
#
#
# X = 'iNeuron'
#
# def func():
#
#     print(X)
#
# func()

# %%
X = 'iNeuron' # defining a variable called iNeuron

def func(): # defining n a funcction with name as func()
    print(X) # this function prints the variable x when called
    
func()    # calling the function
# Out:
# iNeuron

# %% [markdown]
# ## 2. What is the result of the code, and explain?
#
# X = 'iNeuron'
#
# def func():
#
#     X = 'NI!'
#
# func()
#
# print(X)

# %%
X = 'iNeuron' # defining a variable called iNeuron

def func(): # defining a function
    X = 'NI!' # the function returns none because no return or print, it is just assigning the variable X = 'NI!' locally

func() # returns None
print(X) # prints the global X
# Out:
# iNeuron

# %%
print(func())
# Out:
# None

# %% [markdown]
# ## 3. What does this code print, and why?
#
# X = 'iNeuron'
#
# def func():
#
#     X = 'NI'
#
#     print(X)
#
#
# func()
#
# print(X)

# %%
X = 'iNeuron' 

def func():

    X = 'NI'
    
    print(X)
 

func() # the function output is NI becaus elocally it is changing the variable and printing the local X variable

print(X) # once out of the function the global X is printed
# Out:
# NI
# iNeuron

# %% [markdown]
# ## 4. What output does this code produce? Why?
#
# X = 'iNeuron'
#
# def func():
#
#     global X
#
#     X = 'NI'
#
#
# func()
#
# print(X)

# %%
X = 'iNeuron'

def func():

    global X # becauce of the keyword global the local variable X = 'NI' is made a global vatriable and X = 'iNeuron' is updated  to X = 'NI'
    
    X = 'NI'


func()

print(X)
# Out:
# NI

# %% [markdown]
# ## 5. What about this code—what’s the output, and why?
#
#
# X = 'iNeuron'
#
# def func():
#
#     X = 'NI'
#
# def nested():
#
#     print(X)
#
#     nested()
#
#
# func()
# X

# %%
X = 'iNeuron'

def func():

    X = 'NI'
    
    def nested():

        print(X)
    
        nested()


func() ## this is a nested function and the output is the global variable X = 'iNeuron'

X
# Out:
# 'iNeuron'

# %% [markdown]
# ## 6. How about this code: what is its output in Python 3, and explain?
#
#
# def func():
#
#     X = 'NI'
#
#     def nested():
#
#         nonlocal X
#
#         X = 'Spam'
#
# nested()
#
# print(X)
#
# func()

# %%
def func():
    X = 'NI'
    
    def nested():
        nonlocal X
        X = 'Spam'

nested() # the nested function is excuted and the variable X is being printed
# Out:
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# iNeuron
# ...

# %%
print(X) # the previously assigned X is printed because the variables in this function are all locally defined.
         # And anything locaaly definied will extecute only when its function is called.

func()
# Out:
# iNeuron
